# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.stats.stattools import durbin_watson
import statsmodels.api as sm
import scipy.stats as stats
from scipy.special import inv_boxcox
import joblib
import json
import warnings
warnings.filterwarnings("ignore")

# %%
# Configuration
loc = "Your folder path"

# eg . /Users/yourname/Documents/VSCode/End-End Linear Regression- Car Price Prediction/

# %% [markdown]
# ## Load New Dataset

# %%
data_new = pd.read_csv(loc + r"raw/new car data.csv")

# %% [markdown]
# ## Load saved features, model, Box-Cox Lambda Values and Feature Scaler

# %%
# Load model
model = joblib.load("final_model_lr.joblib")

# Load Box-Cox lambdas
fitted_lambda = joblib.load("boxcox_lambda_values.joblib")

# Load feature scaler
scaler = joblib.load("scaler.joblib")

# Load feature list
with open("feature_list.json", "r") as f:
    feature_list = json.load(f)

# %% [markdown]
# ## Data Prepration

# %%
# Convert categorical variables to numerical using OneHotEncoding
data = data_new.copy()
data = pd.get_dummies(data, columns=['Fuel_Type', 'Seller_Type', 'Transmission'], drop_first=True)

# %%
# Create a new feature: Car Age using Year
curr_year = datetime.now().year
data['Car_Age'] = curr_year - data['Year']
data.drop(columns=['Car_Name', 'Year'], inplace=True)  # Drop redundant columns

# %%
# Ensure all expected columns exist
for col in feature_list:
    if col not in data.columns:
        data[col] = 0  # Assign 0 for missing one-hot encoded categories

# %%
# dropping Fuel_Type_Petrol as it was highly correlated with Fuel_Type_Diesel
data.drop(columns=['Fuel_Type_Petrol'], inplace=True)

# %%
# Apply Box-Cox transformation
data_transformed = data.copy()
numerical_features = ['Present_Price', 'Kms_Driven', 'Owner', 'Car_Age']
for col in numerical_features:
    data_transformed[col] = stats.boxcox(data_transformed[col] + 1, fitted_lambda[col])

# %%
# Making sure order of features is same as train data
data_transformed = data_transformed[feature_list]

# %%
# Apply feature scaling
data_scaled = scaler.transform(data_transformed)

# %% [markdown]
# ## Make Predictions on new dataset

# %%
# Predict
predicted_price_transformed = model.predict(data_scaled)

# %%
# Reshape before inverse transform
predicted_price_transformed = predicted_price_transformed.reshape(-1, 1)

# Undo box-cox transformation on target variable
predicted_prices_original = inv_boxcox(predicted_price_transformed, fitted_lambda['Selling_Price']) - 0.1

# add prediction to main df
data_new["Predicted_Selling_Price"] = predicted_prices_original

# %%
data_new
# Out:
#                      Car_Name  Year  Present_Price  Kms_Driven Fuel_Type  \
# 0            Honda Activa 125  2016          0.570       24000    Petrol
# 1                        city  2016         13.600       10980    Petrol
# 2                       verna  2012          9.400       60000    Diesel
# 3               corolla altis  2013         18.610       40001    Petrol
# 4                        ciaz  2015          8.920       42367    Diesel
# 5   Royal Enfield Classic 350  2015          1.470       26000    Petrol
# 6               Yamaha Fazer   2014          0.880        8000    Petrol
# 7        Hero Splender iSmart  2016          0.540       14000    Petrol
# 8                      ertiga  2014          9.950       45000    Diesel
# 9               vitara brezza  2018          9.830        2071    Diesel
# 10  Royal Enfield Classic 350  2013          1.470       33000    Petrol
# 11                       ciaz  2014         12.040       15000    Petrol
# 12                  Activa 4g  2017          0.510        1300    Petrol
# 13                      verna  2013          9.400       45000    Diesel
# 14                       ritz  2013          4.890       64532    Petrol
# 15  Royal Enfield Classic 500  2012          1.750       11500    Petrol
# 16              corolla altis  2017         18.640        8700    Petrol
# 17          Honda Dream Yuga   2017          0.540        8600    Petrol
# 18         UM Renegade Mojave  2017          1.820        1400    Petrol
# 19           Honda CB Trigger  2013          0.730       12000    Petrol
# 20                       city  2016          9.400       19434    Diesel
# 21                      verna  2012          9.400       32322    Diesel
# 22                      swift  2011          4.990       20000    Petrol
# 23       Bajaj Pulsar  NS 200  2014          0.990       25000    Petrol
# 24                        i20  2012          6.790       35000    Petrol
# 25                       city  2013          9.900       56701    Petrol
# 26                 etios liva  2011          5.710       43000    Petrol
# 27  Royal Enfield Classic 350  2017          1.470       11000    Petrol
# 28  Royal Enfield Thunder 350  2016          1.500       18000    Petrol
# 29               Hero Extreme  2013          0.787       16000    Petrol
# 30                       city  2014         14.000       63000    Diesel
# 31     Bajaj Avenger 220 dtsi  2010          0.950       27000    Petrol
# 32                        sx4  2008          7.150       58000    Petrol
# 33                     ertiga  2016         10.790       43000    Diesel
# 34                      amaze  2014          7.000       35000    Petrol
# 35              corolla altis  2013         14.680       72000    Petrol
# 36              corolla altis  2009         18.610       62000    Petrol
# 37                    wagon r  2013          4.410       56879    Petrol
# 38              corolla altis  2010         18.540       50000    Petrol
# 39                     innova  2005         13.700       75000    Petrol
# 40                    corolla  2004         12.350      135154    Petrol
# 41                      amaze  2014          6.400       19000    Petrol
# 42         TVS Apache RTR 160  2014          0.810       42000    Petrol
# 43                    s cross  2015          8.610       33429    Diesel
# 44              Honda CBR 150  2013          1.200       32000    Petrol
# 45                       city  2014         13.600       40126    Petrol
# 46              corolla altis  2010         22.830       80000    Petrol
# 47                        i10  2013          4.600       30000    Petrol
# 48                        i20  2012          6.790       52132    Diesel
#
#    Seller_Type Transmission  Owner  Predicted_Selling_Price
# 0   Individual    Automatic      0                 0.138338
# 1       Dealer       Manual      0                 9.303698
# 2       Dealer       Manual      0                 3.975964
# 3       Dealer       Manual      0                 8.429142
# 4       Dealer       Manual      0                 5.082745
# 5   Individual       Manual      0                 0.268662
# 6   Individual       Manual      0                 0.154021
# 7   Individual       Manual      0                 0.150484
# 8       Dealer       Manual      0                 5.065907
# 9       Dealer       Manual      0                10.248118
# 10  Individual       Manual      0                 0.172938
# 11      Dealer    Automatic      0                 6.736424
# 12  Individual    Automatic      0                 0.262849
# 13      Dealer       Manual      0                 4.441323
# 14      Dealer       Manual      0                 2.291261
# 15  Individual       Manual      0                 0.232837
# 16      Dealer       Manual      0                13.957664
# 17  Individual       Manual      0                 0.229095
# 18  Individual       Manual      0                 0.694293
# 19  Individual       Manual      0                 0.090224
# 20      Dealer       Manual      0                 6.476614
# 21      Dealer       Manual      0                 4.327104
# 22      Dealer       Manual      0                 2.387440
# 23  Individual       Manual      0                 0.138097
# 24      Dealer       Manual      0                 3.166874
# 25      Dealer       Manual      0                 4.508321
# 26      Dealer       Manual      0                 2.457012
# 27  Individual       Manual      0                 0.491835
# 28  Individual       Manual      0                 0.365857
# 29  Individual       Manual      0                 0.092137
# 30      Dealer       Manual      0                 6.599194
# 31  Individual       Manual      0                 0.051278
# 32      Dealer       Manual      0                 2.510042
# 33      Dealer       Manual      0                 6.718569
# 34      Dealer       Manual      0                 3.801828
# 35      Dealer       Manual      0                 6.263860
# 36      Dealer       Manual      0                 6.504905
# 37      Dealer       Manual      0                 2.130394
# 38      Dealer       Manual      0                 6.957587
# 39      Dealer       Manual      0                 4.134652
# 40      Dealer    Automatic      0                 3.227493
# 41      Dealer       Manual      0                 3.751889
# 42  Individual       Manual      0                 0.088504
# 43      Dealer       Manual      0                 5.070336
# 44  Individual       Manual      0                 0.132678
# 45      Dealer       Manual      0                 6.826181
# 46      Dealer    Automatic      0                 7.894686
# 47      Dealer       Manual      0                 2.434019
# 48      Dealer       Manual      0                 2.992542
